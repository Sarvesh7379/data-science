# %% [markdown]
# <a href="https://colab.research.google.com/github/Sarvesh7379/data-science/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Pandas Series**
# ASeries is a one_dimensional labaled array capable of holding any data type. the axis labels are collctive called the index.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # **Creating**  **Series**
# # THere are multiple ways to create a Pandas series

# %%
labels =['a','b','c']
my_list = [10,20,30]
arr = np.array([10,20,30,])
d={1:10,2:30,3:40}

# %%
pd.Series(my_list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(my_list,index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(d)
# Out:
# 1    10
# 2    30
# 3    40
# dtype: int64

# %%
#Data Frame

# %%
#Creating dataframe

# %%
data = {
    'Name':['Alice','Bob','Charlie','lind'],
    'Age':[25,30,35,95],
    'City':['New York','San Francisco','Los Angeles','Landon']
}

# %%
df=pd.DataFrame(data)
# Out:
#       Name  Age           City
# 0    Alice   25       New York
# 1      Bob   30  San Francisco
# 2  Charlie   35    Los Angeles
# 3     lind   95         Landon

# %%
data_list = [
            ['Alice',	25	,'New York',60000],
            ['Bob'	,30,	'San Francisco',560000],
            ['Charlie'	,35,	'Los Angeles',34000],
            ['lind',	95	,'Landon',000000]
            ]
df2=pd.DataFrame(data_list)
df2
# Out:
#          0   1              2       3
# 0    Alice  25       New York   60000
# 1      Bob  30  San Francisco  560000
# 2  Charlie  35    Los Angeles   34000
# 3     lind  95         Landon       0

# %%
col = ['Name','Age','City','Salary']
df2 = pd.DataFrame(data_list,columns=col)
df2
# Out:
#       Name  Age           City  Salary
# 0    Alice   25       New York   60000
# 1      Bob   30  San Francisco  560000
# 2  Charlie   35    Los Angeles   34000
# 3     lind   95         Landon       0

# %%
df2['Name']
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# 3       lind
# Name: Name, dtype: object

# %%
df2[['Name','City']]
# Out:
#       Name           City
# 0    Alice       New York
# 1      Bob  San Francisco
# 2  Charlie    Los Angeles
# 3     lind         Landon

# %%
import pandas as pd
import numpy as np
s = pd.Series([1,3,5,np.nan,6,8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
  dates = pd.date_range("20130101", periods=6)

  dates

  df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list("ABCD"))

  df
# Out:
#                    A         B         C         D
# 2013-01-01  0.291288  0.381746  2.381544  1.404587
# 2013-01-02  2.171966 -0.263132  0.108103 -0.162914
# 2013-01-03 -1.236642  1.289101  0.040483  0.205412
# 2013-01-04 -0.380683  0.678349  0.046000 -1.071332
# 2013-01-05  0.891637 -0.583714 -1.219861 -0.151502
# 2013-01-06 -0.417858 -2.100084 -0.052660  0.413309

# %%
import pandas as pd
import numpy as np

df = pd.read_csv(r'C:\Users\Dell!\Downloads\netflix_titles.csv')   # load data
print(df.head())        # see first 5 rows
print(df.info())        # see column types
print(df.describe())    # see basic statistics
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1292/1612582744.py in <cell line: 0>()
#       2 import numpy as np
#       3
# ----> 4 df = pd.read_csv(r'C:\Users\Dell!\Downloads\netflix_titles.csv')   # load data
#       5 print(df.head())        # see first 5 rows
#       6 print(df.info())        # see column types
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
df = pd.read_csv('https://drive.google.com/drive/home')  # adjust path to where you put it in Drive
df.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /tmp/ipykernel_1292/3739850946.py in <cell line: 0>()
#       3
#       4 import pandas as pd
# ----> 5 df = pd.read_csv('https://drive.google.com/drive/home')  # adjust path to where you put it in Drive
#       6 df.head()
#
# ...

# %%
from google.colab import files
uploaded = files.upload()   # a "Choose Files" button will appear — click it and select netflix_titles.csv from your PC

import pandas as pd
df = pd.read_csv('netflix_titles.csv')
df.head()
# Out:
#      <input type="file" id="files-b89fb116-fae0-4d92-b2cb-a9a885a002bd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b89fb116-fae0-4d92-b2cb-a9a885a002bd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.info()#colum type aur missing values check kro
df.describe()#numeric columns ka summary
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB
# (8807, 12)

# %%
df['type'].value_counts()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# df['director'] = df['director'].fillna('Unknown')
# df['cast'] = df['cast'].fillna('Unknown')
# df['country'] = df['country'].fillna('Unknown')

# %%
most_common_country = df['country'].mode()[0]
df['country'] = df['country'].fillna(most_common_country)

# %%
df.isnull().sum()
# Out:
# show_id          0
# type             0
# title            0
# director         0
# cast             0
# country          0
# date_added      10
# release_year     0
# rating           4
# duration         3
# listed_in        0
# description      0
# dtype: int64
